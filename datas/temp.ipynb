# %%
import pandas as pd

# %%
df = pd.read_csv('devices.csv',encoding='latin-1')
df
# Out:
#                id                                name  \
# 0         3472183   FERREIRA-INTERNATIONAL-MK-PRED-02
# 1         5298309        FERREIRA-INTERNATIONAL-CP-03
# 2         6913752   FERREIRA-INTERNATIONAL-MK-PRED-01
# 3         6930212  FERREIRA-INTERNATIONAL-PLC-CENTRAL
# 4         9706840   FERREIRA-INTERNATIONAL-MK-PRED-03
# ..            ...                                 ...
# 195  441331887217         BRF-LONDRINA-MKPRED-ANX-101
# 196  131331893872                   MYPRO-ANX-GBT-100
# 197  371331908676                   MYPRO-ANX-GBT-200
# 198  871331907702                   MYPRO-ANX-GBT-300
# 199  271331907703                   MYPRO-ANX-GBT-400
#
#                                         owner
# 0    device_SiteManager-FerreiraInternacional
# 1    device_SiteManager-FerreiraInternacional
# 2    device_SiteManager-FerreiraInternacional
# 3    device_SiteManager-FerreiraInternacional
# 4    device_SiteManager-FerreiraInternacional
# ...
